# %% [markdown]
# # Python Homework:
#
# <a href = '#sec1'> Basic arithmetic operations </a>
#
# <a href = '#sec2'> Variables and data types </a>
#
# <a href = '#sec3'>Conditional statements (if-else)</a>
#
# <a href = '#sec4'>Loops (for and while)</a>
#
# <a href = '#sec5'>Functions</a>
#
# <a href = '#sec6'>Lists and tuples</a>

# %% [markdown]
# <a id = 'sec1'></a>
#
# ### Part 1: Basic Arithmetic Operations

# %% [markdown]
# 1. Declare two variables num1 and num2 with values 10 and 5, respectively.

# %% [markdown]
# 2. Calculate and print the sum, difference, product, quotient, and remainder of num1 and num2.

# %% [markdown]
# 3. Declare two more variables num3 and num4 with values 3 and 2, respectively.

# %% [markdown]
# 4. Calculate and print the value of num3 raised to the power of num4.

# %% [markdown]
# <a id = 'sec2'></a>
#
# ### Part 2: Variables and Data Types

# %% [markdown]
# 1. Declare a variable name and assign it the value "John".

# %% [markdown]
# 2. Declare a variable age and assign it the value 25.

# %% [markdown]
# 3. Declare a variable is_student and assign it the value True.

# %% [markdown]
# 4. Declare a variable height and assign it the value 1.75.

# %% [markdown]
# 5. Print out the values of the variables name, age, is_student, and height

# %% [markdown]
# <a id = 'sec3'></a>
#
# ### Part 3: Conditional Statements

# %% [markdown]
# 1. Declare a variable num and assign it a value of your choice.

# %% [markdown]
# 2. Write an if-else statement that prints "Positive" if num is positive, "Negative" if num is negative, and "Zero" if num is zero.

# %% [markdown]
# <a id = 'sec4'></a>
#
# ### Part 4: Loops

# %% [markdown]
# 1. Write a for loop that prints out the numbers from 1 to 10.

# %% [markdown]
# 2. Write a while loop that prints out the numbers from 1 to 10.

# %% [markdown]
# <a id = 'sec5'></a>
#
# ### Part 5: Functions

# %% [markdown]
# 1. Write a function greet that takes a name as a parameter and prints out a greeting message with that name.

# %% [markdown]
# 2. Call the greet function with the name "John".

# %% [markdown]
# <a id = 'sec6'></a>
#
# ### Part 6: Lists and Tuples

# %% [markdown]
# 1. Declare a list fruits with the values "apple", "banana", and "cherry".

# %% [markdown]
# 2. Print out the first and second elements of the fruits list.

# %% [markdown]
# 3. Declare a tuple numbers with the values 1, 2, and 3.

# %% [markdown]
# 4. Print out the third element of the numbers tuple.

# %% [markdown]
# ## Try Again!
