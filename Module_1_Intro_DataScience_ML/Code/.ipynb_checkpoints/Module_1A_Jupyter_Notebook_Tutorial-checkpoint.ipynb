# %% [markdown]
# # Jupyter Notebook Tutorial for Beginners
#
# Welcome to your first Jupyter Notebook! 🎉
#
# This notebook will help you learn how to write and run Python code interactively.

# %% [markdown]
# ## 1 Print Your First Output
# Run the cell below by pressing **Shift + Enter**.

# %%
print("Hello, Jupyter!") #single or double quotation marks
# Out:
# Hello, Jupyter!

# %% [markdown]
# ## 2 Work with Variables
# You can store data in variables and print them.

# %%
name = 'Murat'
age = 25
print('My name is', name, 'and I am', age, 'years old.')
# Out:
# My name is Murat and I am 25 years old.

# %% [markdown]
# ## 3 Do Some Math

# %%
a = 10
b = 5
result = a + b
print('The sum is:', result)
# Out:
# The sum is: 15

# %% [markdown]
# # 4 Add Markdown Text
# ## 4 Add Markdown Text
# ### 4 Add Markdown Text
# This is how you add formatted text in Markdown cells.

# %% [markdown]
# # This is a Heading
# **Bold text**, *italic text*, and bullet lists:
# - Point 1
# - Point 2
# - Point 3

# %% [markdown]
# ## 5 Use Python Libraries

# %%
import math
print('Square root of 16 is:', math.sqrt(16))
# Out:
# Square root of 16 is: 4.0

# %% [markdown]
# ## 6 Create a Simple Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]  # squares

plt.plot(x, y)
plt.title('Simple Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 x = [1, 2, 3, 4, 5]
#       4 y = [i**2 for i in x]  # squares
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## ✅ Summary
# - Code cells → for Python code
# - Markdown cells → for text and notes
# - **Shift + Enter** → run a cell
# - You can save or export your notebook anytime!
